# %% [markdown]
# # INSTALAR LIBRERIAS

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in d:\programacion\pythonuniversidad\analisisdedatos\python\lib\site-packages (5.18.0)
# Requirement already satisfied: tenacity>=6.2.0 in d:\programacion\pythonuniversidad\analisisdedatos\python\lib\site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in d:\programacion\pythonuniversidad\analisisdedatos\python\lib\site-packages (from plotly) (23.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # IMPORTAR LIBRERIAS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # LEER Y MOSTRAR DATASET

# %%
df = pd.read_csv("stores_sales_group_2.csv")
df
# Out:
#      store_id  store_area  items_available  \
# 0           1        1659             1961
# 1           2        1461             1752
# 2           3        1340             1609
# 3           4        1451             1748
# 4           5        1770             2111
# ..        ...         ...              ...
# 891       892        1582             1910
# 892       893        1387             1663
# 893       894        1200             1436
# 894       895        1299             1560
# 895       896        1174             1429
#
#      number_of_customers_who_visited_to_stores  store_sales
# 0                                          530        66490
# 1                                          210        39820
# 2                                          720        54010
# 3                                          620        53730
# 4                                          450        46620
# ..                                         ...          ...
# 891                                       1080        66390
# 892                                        850        82080
# 893                                       1060        76440
# 894                                        770        96610
# 895                                       1110        54340
#
# [896 rows x 5 columns]

# %% [markdown]
# # PREPROCESAMIENTO

# %% [markdown]
# # BUSCAR DATOS NULOS

# %%
df.isnull().mean() * 100
# Out:
# store_id                                     0.0
# store_area                                   0.0
# items_available                              0.0
# number_of_customers_who_visited_to_stores    0.0
# store_sales                                  0.0
# dtype: float64

# %% [markdown]
# # BUSCAR VALORES ATIPICOS

# %%
# Especifica la columna que deseas verificar
column_to_check = 'store_area'  # Reemplaza con el nombre de tu columna

# Estadísticas descriptivas
describe_stats = df[column_to_check].describe()

# Identificar valores atípicos basados en un umbral (puedes ajustar el umbral según tus necesidades)
umbral_atipico = 1.5
outliers = df[df[column_to_check] > describe_stats['75%'] +
              umbral_atipico * (describe_stats['75%'] - describe_stats['25%'])]

# Imprimir el encabezado y los valores atípicos
print(f'Valores atípicos en {column_to_check}:')
print(outliers.to_string(index=False))
# Out:
# Valores atípicos en store_area:
#  store_id  store_area  items_available  number_of_customers_who_visited_to_stores  store_sales
#        92        2169             2617                                        600        67080
#       467        2229             2667                                        660        87410
#       541        2214             2647                                        740        65900

# %%
# Especifica la columna que deseas verificar
column_to_check = 'items_available'  # Reemplaza con el nombre de tu columna

# Estadísticas descriptivas
describe_stats = df[column_to_check].describe()

# Identificar valores atípicos basados en un umbral (puedes ajustar el umbral según tus necesidades)
umbral_atipico = 1.5
outliers = df[df[column_to_check] > describe_stats['75%'] +
              umbral_atipico * (describe_stats['75%'] - describe_stats['25%'])]

# Imprimir el encabezado y los valores atípicos
print(f'Valores atípicos en {column_to_check}:')
print(outliers.to_string(index=False))
# Out:
# Valores atípicos en items_available:
#  store_id  store_area  items_available  number_of_customers_who_visited_to_stores  store_sales
#        92        2169             2617                                        600        67080
#       467        2229             2667                                        660        87410
#       541        2214             2647                                        740        65900

# %%
# Especifica la columna que deseas verificar
# Reemplaza con el nombre de tu columna
column_to_check = 'number_of_customers_who_visited_to_stores'

# Estadísticas descriptivas
describe_stats = df[column_to_check].describe()

# Identificar valores atípicos basados en un umbral (puedes ajustar el umbral según tus necesidades)
umbral_atipico = 1.5
outliers = df[df[column_to_check] > describe_stats['75%'] +
              umbral_atipico * (describe_stats['75%'] - describe_stats['25%'])]

# Imprimir el encabezado y los valores atípicos
print(f'Valores atípicos en {column_to_check}:')
print(outliers.to_string(index=False))
# Out:
# Valores atípicos en number_of_customers_who_visited_to_stores:
#  store_id  store_area  items_available  number_of_customers_who_visited_to_stores  store_sales
#       350        1886             2228                                       1530        40350
#       849         919             1099                                       1560        73810

# %%
# Especifica la columna que deseas verificar
column_to_check = 'store_sales'  # Reemplaza con el nombre de tu columna

# Estadísticas descriptivas
describe_stats = df[column_to_check].describe()

# Identificar valores atípicos basados en un umbral (puedes ajustar el umbral según tus necesidades)
umbral_atipico = 1.5
outliers = df[df[column_to_check] > describe_stats['75%'] +
              umbral_atipico * (describe_stats['75%'] - describe_stats['25%'])]

# Imprimir el encabezado y los valores atípicos
print(f'Valores atípicos en {column_to_check}:')
print(outliers.to_string(index=False))
# Out:
# Valores atípicos en store_sales:
#  store_id  store_area  items_available  number_of_customers_who_visited_to_stores  store_sales
#       650        1989             2414                                        860       116320

# %% [markdown]
# # ANALISIS EXPLORATORIO DE DATOS

# %%
print(df.describe())
# Out:
#          store_id   store_area  items_available  \
# count  896.000000   896.000000       896.000000
# mean   448.500000  1485.409598      1782.035714
# std    258.797218   250.237011       299.872053
# min      1.000000   775.000000       932.000000
# 25%    224.750000  1316.750000      1575.500000
# 50%    448.500000  1477.000000      1773.500000
# 75%    672.250000  1653.500000      1982.750000
# max    896.000000  2229.000000      2667.000000
#
#        number_of_customers_who_visited_to_stores    store_sales
# count                                 896.000000     896.000000
# mean                                  786.350446   59351.305804
# std                                   265.389281   17190.741895
# min                                    10.000000   14920.000000
# 25%                                   600.000000   46530.000000
# 50%                                   780.000000   58605.000000
# 75%                                   970.000000   71872.500000
# max                                  1560.000000  116320.000000

# %%
df.hist(bins=20, figsize=(12, 8))
plt.show()

# %%
df.boxplot(figsize=(12, 8))
plt.show()
